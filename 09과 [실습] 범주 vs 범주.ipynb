# %% [markdown]
# # 9과 [예제] 범주 vs 범주

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import random as rd

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 타이타닉 생존자
# ② 보스톤 시, 타운별 집값
# ③ 아이리스 꽃 분류
# ④ 뉴욕 공기 오염도

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass Title  ... AgeGroup  Family  Mother    Fare2
# 0            1         0       3    Mr  ...   Age_20       2       0   7.2500
# 1            2         1       1   Mrs  ...   Age_30       2       0  71.2833
# 2            3         1       3  Miss  ...   Age_20       1       0   7.9250
# 3            4         1       1   Mrs  ...   Age_30       2       0  53.1000
# 4            5         0       3    Mr  ...   Age_30       1       0   8.0500
#
# [5 rows x 16 columns]

# %%
# 아이리스 꽃 분류
iris = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston2_NA.csv')
boston.head()
# Out:
#       crim  indus  chas    nox     rm  ...  ptratio   black  lstat  medv  zn2
# 0  0.00632   2.31     0  0.538  6.575  ...     15.3  396.90   4.98  24.0  1.0
# 1  0.02731   7.07     0  0.469  6.421  ...     17.8  396.90   9.14  21.6  0.0
# 2  0.02729   7.07     0  0.469  7.185  ...     17.8  392.83   4.03  34.7  0.0
# 3  0.03237   2.18     0  0.458  6.998  ...     18.7  394.63   2.94  33.4  0.0
# 4  0.06905   2.18     0  0.458  7.147  ...     18.7  396.90   5.33  36.2  0.0
#
# [5 rows x 14 columns]

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
air['Month'] = air.Date.dt.month
air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0     41    190.0   7.4    67 1973-05-01      5        1
# 1     36    118.0   8.0    72 1973-05-02      5        2
# 2     12    149.0  12.6    74 1973-05-03      5        3
# 3     18    313.0  11.5    62 1973-05-04      5        4
# 4     19      NaN  14.3    56 1973-05-05      5        5

# %% [markdown]
# ## 2.교차표(pd.crosstab)
# 교차표를 연습해 봅시다.

# %% [markdown]
# ① 타이타닉의 성별에 따른 생존여부의 관계를 교차표로 만들어 봅시다.
# * 전체 갯수

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# * 칼럼기준 비율

# %%
# Out:
# Sex         female      male
# Survived
# 0         0.257962  0.811092
# 1         0.742038  0.188908

# %% [markdown]
# * 행 기준 비율

# %%
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713

# %% [markdown]
# * 전체 기준 비율

# %%
# Out:
# Sex         female      male
# Survived
# 0         0.090909  0.525253
# 1         0.261504  0.122334

# %% [markdown]
# * 교차표를 통해 성별에 따라 생존여부가 관련 있다고 보이나요?
# * 위 교차표 중 어떤 것이 성별-->생존여부 관련성을 확인하기에 적합한가요?

# %% [markdown]
# ② 타이타닉의 객실등급에 따른 생존여부의 관계를 교차표로 만들어 봅시다.
# * 전체 갯수

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# * 칼럼기준 비율

# %%
# Out:
# Pclass          1         2         3
# Survived
# 0         0.37037  0.527174  0.757637
# 1         0.62963  0.472826  0.242363

# %% [markdown]
# * 행 기준 비율

# %%
# Out:
# Pclass           1         2         3
# Survived
# 0         0.145719  0.176685  0.677596
# 1         0.397661  0.254386  0.347953

# %% [markdown]
# * 전체 기준 비율

# %%
# Out:
# Pclass           1         2         3
# Survived
# 0         0.089787  0.108866  0.417508
# 1         0.152637  0.097643  0.133558

# %% [markdown]
# * 교차표를 통해 객실 등급에 따라 생존여부가 관련 있다고 보이나요?
# * 위 교차표 중 어떤 것이 성별-->생존여부 관련성을 확인하기에 적합한가요?

# %% [markdown]
# ③ 성별과 객실등급 중 어떤 변수가 생존여부를 예측하는데 더 중요한 변수인가요?

# %% [markdown]
# ## 3.시각화 : bar chart, mosaic

# %% [markdown]
# ① Sex --> Survived
# * 100% bar chart을 그려봅시다.

# %%
# Out:
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %% [markdown]
# * 모자익 플롯을 그려봅시다.

# %%
# Pclass별 생존여부를 mosaic plot으로 그려 봅시다.

# %% [markdown]
# * 두 차트로 볼 때, 성별에 따라 생존여부가 달라지나요?

# %% [markdown]
# ② Pclass --> Survived
# * 100% bar chart을 그려봅시다.

# %%
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %% [markdown]
# * 모자익 플롯을 그려봅시다.

# %%
# Pclass별 생존여부를 mosaic plot으로 그려 봅시다.

# %% [markdown]
# * 두 차트로 볼 때, 성별에 따라 생존여부가 달라지나요?

# %% [markdown]
# ## 4.수치화 : 카이제곱검정

# %% [markdown]
# ① Sex --> Survived

# %%
# 먼저 집계


# 카이제곱검정

# %% [markdown]
# ② Pclass --> Survived

# %%
# 먼저 집계


# 카이제곱검정
